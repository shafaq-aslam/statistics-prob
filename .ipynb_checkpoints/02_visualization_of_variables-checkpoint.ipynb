# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
import pandas as pd
df = pd.read_csv("demographic.csv")

# %%
df.columns
# Out:
# Index(['SEQN', 'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN',
#        'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'RIDEXAGM', 'DMQMILIZ', 'DMQADFC',
#        'DMDBORN4', 'DMDCITZN', 'DMDYRSUS', 'DMDEDUC3', 'DMDEDUC2', 'DMDMARTL',
#        'RIDEXPRG', 'SIALANG', 'SIAPROXY', 'SIAINTRP', 'FIALANG', 'FIAPROXY',
#        'FIAINTRP', 'MIALANG', 'MIAPROXY', 'MIAINTRP', 'AIALANGA', 'DMDHHSIZ',
#        'DMDFMSIZ', 'DMDHHSZA', 'DMDHHSZB', 'DMDHHSZE', 'DMDHRGND', 'DMDHRAGE',
#        'DMDHRBR4', 'DMDHREDU', 'DMDHRMAR', 'DMDHSEDU', 'WTINT2YR', 'WTMEC2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDHHIN2', 'INDFMIN2', 'INDFMPIR'],
#       dtype='str')

# %% [markdown]
# # Discrete Values

# %%
gender = df['RIAGENDR']
gender.value_counts()
# Out:
# RIAGENDR
# 2    5172
# 1    5003
# Name: count, dtype: int64

# %%
gender.value_counts().plot(kind='bar')
plt.show()

# %%
# To create labels
gender.value_counts().plot(kind='bar')
plt.xticks([0, 1], ['Male', 'Female'])
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Most Common Values

# %%
sizes = np.array([22, 23, 29, 32, 39, 42, 42, 42, 42, 42, 42, 42, 42, 43, 44, 46, 51, 51, 55, 55, 57, 58, 78, 83, 97, 97])

# %%
sizes.mean()
# Out:
# np.float64(49.84615384615385)

# %%
from collections import Counter
count = Counter()

for size in sizes:
    count[size] += 1

count.most_common()
# Out:
# [(np.int64(42), 8),
#  (np.int64(51), 2),
#  (np.int64(55), 2),
#  (np.int64(97), 2),
#  (np.int64(22), 1),
#  (np.int64(23), 1),
#  (np.int64(29), 1),
#  (np.int64(32), 1),
#  (np.int64(39), 1),
#  (np.int64(43), 1),
#  (np.int64(44), 1),
#  (np.int64(46), 1),
#  (np.int64(57), 1),
#  (np.int64(58), 1),
#  (np.int64(78), 1),
#  (np.int64(83), 1)]

# %% [markdown]
# #### Alternative method

# %%
# Use scipy library
# !pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.8/37.3 MB 3.6 MB/s eta 0:00:11
#    - -------------------------------------- 1.6/37.3 MB 4.1 MB/s eta 0:00:09
#    -- ------------------------------------- 2.1/37.3 MB 3.5 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/37.3 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/37.3 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/37.3 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.4/37.3 MB 3.3 MB/s eta 0:00:11
#    -- ------------------------------------- 2.6/37.3 MB 1.5 MB/s eta 0:00:24
#    -- ------------------------------------- 2.6/37.3 MB 1.5 MB/s eta 0:00:24
#    --- ------------------------------------ 3.4/37.3 MB 1.6 MB/s eta 0:00:22
# ...

# %%
from scipy import stats

# %%
stats.mode(sizes) # index 0 has value, index 1 has count
# Out:
# ModeResult(mode=np.int64(42), count=np.int64(8))

# %%
# panda's mode
gender.mode() # index is 0, 2 is value
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender) # index 0 has value, index 1 has frequency
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(5172))

# %% [markdown]
# #### More than One "Classes"

# %%
df['RIDRETH3'].unique()
# Out:
# array([4, 3, 1, 2, 7, 6])

# %%
df['RIDRETH1'].value_counts().plot(kind='bar')
plt.show()

# %%
# Not recommended!
df['RIDRETH1'].value_counts().plot(kind='pie')
plt.show()

# %% [markdown]
# # Studying Real-Valued Numbers

# %%
df.head(20)
# Out:
#      SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0   73557         8         2         1        69       NaN         4
# 1   73558         8         2         1        54       NaN         3
# 2   73559         8         2         1        72       NaN         3
# 3   73560         8         2         1         9       NaN         3
# 4   73561         8         2         2        73       NaN         3
# 5   73562         8         2         1        56       NaN         1
# 6   73563         8         2         1         0       5.0         3
# 7   73564         8         2         2        61       NaN         3
# 8   73565         8         1         1        42       NaN         2
# 9   73566         8         2         2        56       NaN         3
# 10  73567         8         2         1        65       NaN         3
# 11  73568         8         2         2        26       NaN         3
# ...

# %%
dt = df['WTINT2YR']

# %%
dt.value_counts().plot(kind='bar') # this will not work at all here
plt.show()

# %%
# when bins are less, understanding will be better and loss of information
# when bins are more, understanding less but will get more information about the data
dt.hist(bins=4) 
plt.show()

# %%
dt.hist(bins=10) 
plt.show()

# %%
dt.hist(bins=20) 
plt.show()

# %%
dt.hist(bins=100) 
plt.show()

# %% [markdown]
# ## Custom Matplotlib Histogram

# %%
plt.hist(dt, bins=45)
plt.ylabel("Frequency")
plt.xlabel("Data")
plt.title("Histogram of Data in NHANES (Demographic) Dataset")
plt.show()

# %% [markdown]
# ## Prettifying and Styling Matplotlib with Seaborn

# %%
# !pip install seaborn

# %%
import seaborn as sns
sns.set(color_codes = True)
sns.set_style("white")

# %%
sns.distplot(dt, bins = 35, kde = False)
plt.ylabel("Frequency")
plt.xlabel("Data")
plt.title("Histogram of Data in NHANES (Demographic) Dataset")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16200\1342182676.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt, bins = 35, kde = False)

# %%
sns.distplot(dt, bins = 35)
plt.ylabel("Frequency")
plt.xlabel("Data")
plt.title("Histogram of Data in NHANES (Demographic) Dataset")
sns.despine(offset=10, trim=True) # move axes away
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16200\1969428610.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt, bins = 35)
