# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("demographic.csv")
df
# Out:
#         SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0      73557         8         2         1        69       NaN         4
# 1      73558         8         2         1        54       NaN         3
# 2      73559         8         2         1        72       NaN         3
# 3      73560         8         2         1         9       NaN         3
# 4      73561         8         2         2        73       NaN         3
# ...      ...       ...       ...       ...       ...       ...       ...
# 10170  83727         8         2         1        26       NaN         2
# 10171  83728         8         2         2         2      24.0         1
# 10172  83729         8         2         2        42       NaN         4
# 10173  83730         8         2         1         7       NaN         2
# 10174  83731         8         2         1        11       NaN         5
#
#        RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# ...

# %%
df.columns
# Out:
# Index(['SEQN', 'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN',
#        'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'RIDEXAGM', 'DMQMILIZ', 'DMQADFC',
#        'DMDBORN4', 'DMDCITZN', 'DMDYRSUS', 'DMDEDUC3', 'DMDEDUC2', 'DMDMARTL',
#        'RIDEXPRG', 'SIALANG', 'SIAPROXY', 'SIAINTRP', 'FIALANG', 'FIAPROXY',
#        'FIAINTRP', 'MIALANG', 'MIAPROXY', 'MIAINTRP', 'AIALANGA', 'DMDHHSIZ',
#        'DMDFMSIZ', 'DMDHHSZA', 'DMDHHSZB', 'DMDHHSZE', 'DMDHRGND', 'DMDHRAGE',
#        'DMDHRBR4', 'DMDHREDU', 'DMDHRMAR', 'DMDHSEDU', 'WTINT2YR', 'WTMEC2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDHHIN2', 'INDFMIN2', 'INDFMPIR'],
#       dtype='str')

# %%
df['RIDEXAGM']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3        119.0
# 4          NaN
#          ...
# 10170      NaN
# 10171     24.0
# 10172      NaN
# 10173     84.0
# 10174    140.0
# Name: RIDEXAGM, Length: 10175, dtype: float64

# %% [markdown]
# # Studying Central Tendency

# %%
plt.figure(figsize = (20, 5))

x = range(df['RIDAGEYR'].size)
y = df['RIDAGEYR']

plt.scatter(x, y, marker='x', s=0.5)

plt.title("Data of Individual")
plt.xlabel("ID of Individual")
plt.ylabel("Data")

# plot the estimate line 
p1 = (0, 10)
p2 = (10200, 10)
x_c, y_c = zip(p1, p2)
plt.plot(x_c, y_c, color='red', linewidth=0.75)
plt.show()

# %%
dt = df['RIDAGEYR']
dt.mean()
# Out:
# np.float64(31.484127764127763)

# %%
plt.figure(figsize = (20, 5))

x = range(df['RIDAGEYR'].size)
y = df['RIDAGEYR']

plt.scatter(x, y, marker='x', s=0.5)

plt.title("Data of Individual")
plt.xlabel("ID of Individual")
plt.ylabel("Data")

# plot the estimate line 
x_c, y_c = ([0, 10110], [10, 10])
plt.plot(x_c, y_c, color='red', linewidth=0.75)

x_c, y_c = ([0, 10110], [dt.mean(), dt.mean()])
plt.plot(x_c, y_c, color = 'green', linewidth=2)
plt.show()

# %% [markdown]
# ## Problem with Arithmetic Mean

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])

# %%
nums.mean()
# Out:
# np.float64(30.625)

# %%
# just did sligthly change in data
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 200])

# %%
# Just because of 1 number that I changed from 97 to 200, means jumped.
np.mean(nums)
# Out:
# np.float64(37.0625)
